# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Box Plot

# %% [markdown]
# * Box: The box represents the interquartile range (IQR), which is the range between the first quartile (Q1 or 25th percentile) and the third quartile (Q3 or 75th percentile). The box's length depicts the spread of the middle 50% of the data.
#
#
# * Median Line: A line inside the box represents the median (Q2 or 50th percentile), which divides the data into two equal halves.
#
#
# * Whiskers: The lines extending from the box are called whiskers. They represent the minimum and maximum values within a certain range, typically 1.5 times the IQR from the box edges. Any data points beyond the whiskers are considered outliers.
#
#
# * Outliers: Outliers are data points that lie an abnormal distance from the rest of the data. They are usually plotted as individual points beyond the whiskers.

# %%
# Generate random data
data = np.random.normal(0, 1, 1000)

# Create a box plot
plt.figure(figsize=(8, 6))
plt.boxplot(data)
plt.title("Box Plot Example")
plt.show()

# %%
data
# Out:
# array([-5.78783897e-01, -1.91131170e+00, -8.59488805e-01,  1.43272520e+00,
#        -1.18665513e+00,  3.44547313e-01, -2.46803407e-01,  1.54507198e+00,
#        -1.22747888e+00, -7.51982699e-01,  1.35098347e-01,  2.81745640e-01,
#        -1.68480003e+00, -5.15872091e-02, -8.55524578e-01,  4.76251855e-02,
#        -6.34396077e-01, -1.04434915e+00,  1.23900477e+00,  8.60587247e-01,
#        -7.70486521e-01,  7.56710701e-01,  2.97185165e-01,  7.21974750e-01,
#         9.30179366e-01, -8.96798481e-01, -8.49484777e-01, -1.45281651e+00,
#        -6.57313056e-01, -5.08834539e-01, -1.16983537e+00,  2.00795703e+00,
#         8.15733863e-01, -2.57232117e-01, -3.84603846e-02,  1.99855186e+00,
#        -1.35084751e+00, -1.07829081e+00,  4.11293199e-01, -4.68178202e-01,
#        -2.75970720e-01,  3.00235132e-01,  4.00428491e-01,  2.08725319e+00,
#         1.54947525e+00,  2.15856819e+00, -2.77864287e-01,  1.04694848e+00,
#        -1.79386437e-01, -1.00264676e-01, -4.97138790e-01, -5.23241614e-01,
#         1.36737947e-01, -5.43589310e-03,  9.92510187e-01, -1.68074676e+00,
#        -6.03697012e-01,  1.55843303e+00,  2.80868690e+00, -2.64020844e-01,
#        -6.51567821e-01, -3.11960460e+00, -2.64754400e-01, -9.23320800e-01,
#         1.39843481e-01,  6.62302474e-01,  3.35336761e+00,  5.13301300e-01,
#         1.02547374e+00,  7.60720483e-01, -9.74650117e-02,  7.86601161e-01,
#         3.38554588e-01, -5.98507210e-01, -1.48342550e-01, -6.93209650e-01,
#         1.41386474e+00, -7.56917723e-01,  3.74771114e-01,  1.33339031e-01,
#         7.76680363e-01,  2.09779491e-01, -1.49597475e+00,  1.89970802e+00,
#        -7.20261557e-01, -5.90521657e-01,  5.73812736e-01, -8.62655380e-02,
#        -4.20148398e-01, -4.65855889e-01, -3.18542594e-01,  1.15305621e+00,
#         8.78028132e-01,  1.45875832e+00, -8.37430743e-01, -9.70263527e-01,
#         8.26286222e-01,  7.12520789e-01,  2.67850163e-01,  1.08111188e+00,
#         1.29090714e+00,  2.11548794e+00, -1.19001776e+00, -1.21956386e+00,
#        -4.18121051e-02,  1.06387002e+00, -5.68554638e-01, -6.63212313e-02,
#        -1.04950189e-01, -8.91648518e-02, -2.18727612e-01,  2.56400590e-02,
#         7.28362601e-01, -1.46692071e+00,  3.14972247e-01, -1.97454698e+00,
#        -1.38618672e+00, -1.48366034e+00,  3.40097644e-01,  2.27759093e-02,
#         1.76390335e+00, -7.02316770e-01, -2.41691828e+00, -8.55599785e-01,
#        -9.60377325e-01,  1.87972825e-01, -1.08776188e-01,  1.47117888e+00,
#         7.09915057e-01, -8.25324417e-01, -1.00256323e+00,  2.18291412e-01,
#         8.29396517e-01,  3.54082794e-01, -1.95206591e-01, -1.05148655e+00,
#         1.15699437e+00, -1.56271666e+00, -2.46023169e-01,  1.50800430e-02])

# %% [markdown]
# # Interpreting Box Plots
# The box plot provides a visual summary of the data's distribution, including:
# * Center: The median line represents the center of the data.
# * Spread: The box's length indicates the spread of the middle 50% of the data.
# * Skewness: If the median line is not centered within the box, the data may be skewed.
# * Outliers: Outliers are easily identifiable as individual points beyond the whiskers.

# %%
# Generate data for multiple groups
group1 = np.random.normal(0, 1, 100)
group2 = np.random.normal(2, 1, 100)
group3 = np.random.normal(-1, 1, 100)

# Create a box plot with multiple groups
plt.figure(figsize=(10, 6))
plt.boxplot([group1, group2, group3], patch_artist=True, labels=["Group 1", "Group 2", "Group 3"])
plt.title("Box Plot with Multiple Groups")
plt.show()

# %%
# Descriptive Statistics


# Sample data
data = {
    'values': [12, 15, 14, 10, 8, 10, 9, 7, 13, 12, 16, 14, 15, 14, 12, 10, 9, 10, 15, 13]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Calculate Measures of Central Tendency
mean_value = df['values'].mean()
median_value = df['values'].median()
mode_value = df['values'].mode()[0]

# Calculate Measures of Variability
range_value = df['values'].max() - df['values'].min()
variance_value = df['values'].var()
std_deviation_value = df['values'].std()



# Print the results
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Mode: {mode_value}")
print(f"Range: {range_value}")
print(f"Variance: {variance_value}")
print(f"Standard Deviation: {std_deviation_value}")
# Out:
# Mean: 11.9
# Median: 12.0
# Mode: 10
# Range: 9
# Variance: 6.936842105263159
# Standard Deviation: 2.6337885460422137

# %% [markdown]
# We can calculate the standard deviation manually using the formula:
# ![image.png](attachment:image.png)
#
# Measuring variability: The primary use of standard deviation is to quantify the amount of variation or dispersion present in a dataset. A low standard deviation indicates that the data points tend to be clustered closely around the mean, while a high standard deviation suggests that the data is more spread out over a wider range of values.

# %% [markdown]
# # How to use Merge in Pandas

# %% [markdown]
# In this lab, we'll learn how to merge two data frames together using different types of joins. We'll use a sample dataset of employees and their departments.
#
# https://pandas.pydata.org/docs/reference/api/pandas.merge.html
#
# ![image.png](attachment:image.png)

# %%
# Create sample data frames
employees = pd.DataFrame({'EmpID': [1, 2, 3, 4, 5],
                           'Name': ['John', 'Jane', 'Bob', 'Alice', 'Mike'],
                           'Age': [32, 28, 45, 37, 51]})

departments = pd.DataFrame({'DeptID': [1, 2, 3, 4, 10],
                             'DeptName': ['Sales', 'IT', 'HR', 'Finance', 'Boss'],
                             'EmpID': [1, 3, 2, 4,6]})

print('Employees:')
print(employees)
print('\nDepartments:')
print(departments)
# Out:
# Employees:
#    EmpID   Name  Age
# 0      1   John   32
# 1      2   Jane   28
# 2      3    Bob   45
# 3      4  Alice   37
# 4      5   Mike   51
#
# Departments:
#    DeptID DeptName  EmpID
# 0       1    Sales      1
# 1       2       IT      3
# 2       3       HR      2
# 3       4  Finance      4
# 4      10     Boss      6

# %% [markdown]
# # Inner Join
# An inner join returns a new data frame containing only the rows where the merge key values exist in both data frames.

# %%
# Perform an inner join
merged_inner = pd.merge(employees, departments, left_on='EmpID', right_on='EmpID', how='inner')
print('\nInner Join:')
print(merged_inner)
# Out:
# Inner Join:
#    EmpID   Name  Age  DeptID DeptName
# 0      1   John   32       1    Sales
# 1      2   Jane   28       3       HR
# 2      3    Bob   45       2       IT
# 3      4  Alice   37       4  Finance

# %% [markdown]
# # Left Join
# A left join returns a new data frame containing all rows from the left data frame and only the matching rows from the right data frame. Non-matching rows in the right data frame will have NaN values.

# %%
# Perform a left join
merged_left = pd.merge(employees, departments, left_on='EmpID', right_on='EmpID', how='left')
print('\nLeft Join:')
print(merged_left)
# Out:
# Left Join:
#    EmpID   Name  Age  DeptID DeptName
# 0      1   John   32     1.0    Sales
# 1      2   Jane   28     3.0       HR
# 2      3    Bob   45     2.0       IT
# 3      4  Alice   37     4.0  Finance
# 4      5   Mike   51     NaN      NaN

# %% [markdown]
# # Right Join
# A right join is the opposite of a left join. It returns a new data frame containing all rows from the right data frame and only the matching rows from the left data frame. Non-matching rows in the left data frame will have NaN values.

# %%
# Perform a right join
merged_right = pd.merge(employees, departments, left_on='EmpID', right_on='EmpID', how='right')
print('\nRight Join:')
print(merged_right)
# Out:
# Right Join:
#    EmpID   Name   Age  DeptID DeptName
# 0      1   John  32.0       1    Sales
# 1      3    Bob  45.0       2       IT
# 2      2   Jane  28.0       3       HR
# 3      4  Alice  37.0       4  Finance
# 4      6    NaN   NaN      10     Boss

# %% [markdown]
# # Outer Join
# An outer join returns a new data frame containing all rows from both data frames, combining rows with matching merge key values and filling in NaN for non-matching rows.

# %%
# Perform an outer join
merged_outer = pd.merge(employees, departments, left_on='EmpID', right_on='EmpID', how='outer')
print('\nOuter Join:')
print(merged_outer)
# Out:
# Outer Join:
#    EmpID   Name   Age  DeptID DeptName
# 0      1   John  32.0     1.0    Sales
# 1      2   Jane  28.0     3.0       HR
# 2      3    Bob  45.0     2.0       IT
# 3      4  Alice  37.0     4.0  Finance
# 4      5   Mike  51.0     NaN      NaN
# 5      6    NaN   NaN    10.0     Boss

# %% [markdown]
# # Lab

# %%
df_reviews = pd.read_csv('../data/reviews.csv')
df_submissions = pd.read_csv('../data/Submissions.csv')

df_combined = pd.read_csv('https://raw.githubusercontent.com/raymondEDS/VRM-E/main/data/raw/df_submission_rating.csv')

# %%
df_submissions.head()
# Out:
#             id      original        tcdate        tmdate  number  \
# 0  r28GdiQF7vM   YaMZTQ7VXt2  1.601310e+12  1.635170e+12     546
# 1  o29tNZZqGcN  w4nLEWLcq9ZN  1.601310e+12  1.633020e+12    1000
# 2  Wj4ODo0uyCF   EGD9_RwnpMs  1.601310e+12  1.632760e+12    3265
# 3   _qJXkf347k    7LgLMxopN9  1.601310e+12  1.632380e+12    1892
# 4   LGgdb4TS4Z    c4RxVOgHI1  1.601310e+12  1.632240e+12    2141
#
#                                                title  \
# 0  Sharper Generalization Bounds for Learning wit...
# 1  Bridging Graph Network to Lifelong Learning wi...
# 2  Share or Not? Learning to Schedule Language-Sp...
# 3  Reinforcement Learning Based Asymmetrical DNN ...
# 4  Topology-Aware Segmentation Using Discrete Mor...
#
#                                            authorids  \
# 0                  ["~Yunwen_Lei1", "~Yiming_Ying1"]
# 1  ["~Chen_Wang2", "~Yuheng_Qiu1", "~Sebastian_Sc...
# 2  ["~Biao_Zhang2", "~Ankur_Bapna1", "~Rico_Sennr...
# 3  ["~Brijraj_Singh1", "ya.jain@samsung.com", "~M...
# 4  ["~Xiaoling_Hu1", "~Yusu_Wang1", "~Li_Fuxin1",...
#
#                                              authors  \
# 0                      ["Yunwen Lei", "Yiming Ying"]
# 1   ["Chen Wang", "Yuheng Qiu", "Sebastian Scherer"]
# 2  ["Biao Zhang", "Ankur Bapna", "Rico Sennrich",...
# 3  ["Brijraj Singh", "Yash Jain", "Mayukh Das", "...
# 4  ["Xiaoling Hu", "Yusu Wang", "Li Fuxin", "Dimi...
#
#                                             keywords  \
# 0   ["generalization bounds", "non-convex learning"]
# 1     ["Graph Neural Network", "Continual Learning"]
# 2  ["language-specific modeling", "conditional co...
# 3                ["DNN Compression", "Loading time"]
# 4  ["Topology", "Morse theory", "Image segmentati...
#
#                                             abstract  \
# 0  Stochastic optimization has become the workhor...
# 1  Graph neural networks (GNN) are powerful model...
# 2  Using a mix of shared and language-specific (L...
# 3  Latency of DNN (Deep Neural Network) based pre...
# 4  In the segmentation of fine-scale structures f...
#
#                                                  pdf conf_name  conf_year  \
# 0  /pdf/43ac8e3a506c7ad54162957c4698675f659e050a.pdf      ICLR       2021
# 1  /pdf/dd7ff523aa1bd5d49e10f887e350de2ee909023a.pdf      ICLR       2021
# 2  /pdf/daf5088c43f0425f9ab145f2bb0b1db43092147f.pdf      ICLR       2021
# 3  https://openreview.net/references/pdf?id=x1Fun...      ICLR       2021
# 4  /pdf/e328a81d734d6f9eb2808b309985c8aeffb1b27b.pdf      ICLR       2021
#
#                                                 tldr
# 0  We develop sharper generalization bounds for l...
# 1  We propose a graph topology  to overcome the d...
# 2  We investigate and improve parameter-sharing s...
# 3  This work proposes an application of reinforce...
# 4  This paper proposes a loss based on discrete M...

# %%
df_reviews.head()
# Out:
#             id  number        forum      replyto  \
# 0  kOJs5_dKXyW       4  tGZu6DlbreV  tGZu6DlbreV
# 1  kbedPNPDFwa       1  uKhGRvM8QNH  uKhGRvM8QNH
# 2  zgzRcwaItum       2   IrM64DGB21   IrM64DGB21
# 3  ZJ_1Qi4LbUb       2  ww-7bdU6GA9  ww-7bdU6GA9
# 4   Bbp-JccEu-       3  j0uePNuoBho  j0uePNuoBho
#
#                                                title  \
# 0  Review of "RNNLogic: Learning Logic Rules for ...
# 1  This paper proposes two knowledge distillation...
# 2  Needs to rephrase claims and design experiment...
# 3  Paper that has good contributions for analyzin...
# 4      Review of the paper Learned Threshold Pruning
#
#                                               review  rating_int  \
# 0  There is a lot of recent work on link-predicti...           6
# 1  Pros:\n\n- The different attention techniques ...           6
# 2  Overview of the paper: \nThis paper studies th...           5
# 3  ## Summary\nThe authors propose a near minimax...           6
# 4  The paper proposed a new method to prune a neu...           6
#
#    confidence_int conf_name
# 0             4.0  ICLR2021
# 1             4.0  ICLR2021
# 2             4.0  ICLR2021
# 3             3.0  ICLR2021
# 4             4.0  ICLR2021

# %%
df_average_review_score = df_reviews.groupby('forum')['rating_int'].mean()
df_average_review_score
# Out:
# forum
# #NAME?         5.479730
# -2FCwDKRREu    7.666667
# -5VpoDCExrU    4.750000
# -5W5OBfFlwX    4.000000
# -6vS_4Kfz0     6.250000
#                  ...
# zsKWh2pRSBK    4.750000
# zspml_qcldq    4.000000
# ztMLindFLWR    5.800000
# zv-typ1gPxA    7.000000
# zx_uX-BO7CH    6.500000
# Name: rating_int, Length: 7592, dtype: float64

# %%
df_average_review_score = df_average_review_score.reset_index()
df_average_review_score
# Out:
#             forum  rating_int
# 0          #NAME?    5.479730
# 1     -2FCwDKRREu    7.666667
# 2     -5VpoDCExrU    4.750000
# 3     -5W5OBfFlwX    4.000000
# 4      -6vS_4Kfz0    6.250000
# ...           ...         ...
# 7587  zsKWh2pRSBK    4.750000
# 7588  zspml_qcldq    4.000000
# 7589  ztMLindFLWR    5.800000
# 7590  zv-typ1gPxA    7.000000
# 7591  zx_uX-BO7CH    6.500000
#
# [7592 rows x 2 columns]

# %%
df_submission_score = pd.merge(df_submissions, df_average_review_score, left_on='id', right_on='forum', how = 'inner')
df_submission_score
# Out:
#                id      original        tcdate        tmdate  number  \
# 0     r28GdiQF7vM   YaMZTQ7VXt2  1.601310e+12  1.635170e+12     546
# 1     o29tNZZqGcN  w4nLEWLcq9ZN  1.601310e+12  1.633020e+12    1000
# 2     Wj4ODo0uyCF   EGD9_RwnpMs  1.601310e+12  1.632760e+12    3265
# 3      _qJXkf347k    7LgLMxopN9  1.601310e+12  1.632380e+12    1892
# 4      LGgdb4TS4Z    c4RxVOgHI1  1.601310e+12  1.632240e+12    2141
# ...           ...           ...           ...           ...     ...
# 7622    BkfiXiUlg           NaN  1.478040e+12  1.478040e+12      34
# 7623    SkqMSCHxe           NaN  1.477990e+12  1.477990e+12      28
# 7624    rJXTf9Bxg           NaN  1.477970e+12  1.477970e+12      27
# 7625    S1HEBe_Jl           NaN  1.477080e+12  1.477080e+12       6
# 7626    S1J0E-71l           NaN  1.476760e+12  1.476850e+12       2
#
#                                                   title  \
# 0     Sharper Generalization Bounds for Learning wit...
# 1     Bridging Graph Network to Lifelong Learning wi...
# 2     Share or Not? Learning to Schedule Language-Sp...
# 3     Reinforcement Learning Based Asymmetrical DNN ...
# 4     Topology-Aware Segmentation Using Discrete Mor...
# ...                                                 ...
# 7622  Learning Efficient Algorithms with Hierarchica...
# 7623  PREDICTION OF POTENTIAL HUMAN INTENTION USING ...
# 7624  Conditional Image Synthesis With Auxiliary Cla...
# 7625  Learning to Protect Communications with Advers...
# 7626    Surprisal-Driven Feedback in Recurrent Networks
#
#                                               authorids  \
# 0                     ["~Yunwen_Lei1", "~Yiming_Ying1"]
# 1     ["~Chen_Wang2", "~Yuheng_Qiu1", "~Sebastian_Sc...
# 2     ["~Biao_Zhang2", "~Ankur_Bapna1", "~Rico_Sennr...
# 3     ["~Brijraj_Singh1", "ya.jain@samsung.com", "~M...
# 4     ["~Xiaoling_Hu1", "~Yusu_Wang1", "~Li_Fuxin1",...
# ...                                                 ...
# 7622        ["marcin@openai.com", "kkurach@google.com"]
# 7623  ["masayoshi.ishikawa.gv@hitachi.com", "mariko....
# 7624  ["augustusodena@google.com", "colah@google.com...
# 7625             ["abadi@google.com", "dga@google.com"]
# 7626                             ["kmrocki@us.ibm.com"]
#
#                                                 authors  \
# 0                         ["Yunwen Lei", "Yiming Ying"]
# 1      ["Chen Wang", "Yuheng Qiu", "Sebastian Scherer"]
# 2     ["Biao Zhang", "Ankur Bapna", "Rico Sennrich",...
# 3     ["Brijraj Singh", "Yash Jain", "Mayukh Das", "...
# 4     ["Xiaoling Hu", "Yusu Wang", "Li Fuxin", "Dimi...
# ...                                                 ...
# 7622            ["Marcin Andrychowicz", "Karol Kurach"]
# 7623  ["Masayoshi Ishikawa", "Mariko Okude", "Takehi...
# 7624  ["Augustus Odena", "Christopher Olah", "Jonath...
# 7625         ["Mart\u00edn Abadi", "David G. Andersen"]
# 7626                                    ["Kamil Rocki"]
#
#                                                keywords  \
# 0      ["generalization bounds", "non-convex learning"]
# 1        ["Graph Neural Network", "Continual Learning"]
# 2     ["language-specific modeling", "conditional co...
# 3                   ["DNN Compression", "Loading time"]
# 4     ["Topology", "Morse theory", "Image segmentati...
# ...                                                 ...
# 7622                                                 []
# 7623  ["Computer vision", "Deep learning", "Supervis...
# 7624                                  ["Deep learning"]
# 7625                                                 []
# 7626  ["Unsupervised Learning", "Applications", "Dee...
#
#                                                abstract  \
# 0     Stochastic optimization has become the workhor...
# 1     Graph neural networks (GNN) are powerful model...
# 2     Using a mix of shared and language-specific (L...
# 3     Latency of DNN (Deep Neural Network) based pre...
# 4     In the segmentation of fine-scale structures f...
# ...                                                 ...
# 7622  In this paper, we propose and investigate a no...
# 7623  We propose a learning method to quantify human...
# 7624  Synthesizing high resolution photorealistic im...
# 7625  We ask whether neural networks can learn to us...
# 7626  Recurrent neural nets are widely used for pred...
#
#                                                     pdf conf_name  conf_year  \
# 0     /pdf/43ac8e3a506c7ad54162957c4698675f659e050a.pdf      ICLR       2021
# 1     /pdf/dd7ff523aa1bd5d49e10f887e350de2ee909023a.pdf      ICLR       2021
# 2     /pdf/daf5088c43f0425f9ab145f2bb0b1db43092147f.pdf      ICLR       2021
# 3     https://openreview.net/references/pdf?id=x1Fun...      ICLR       2021
# 4     /pdf/e328a81d734d6f9eb2808b309985c8aeffb1b27b.pdf      ICLR       2021
# ...                                                 ...       ...        ...
# 7622  /pdf/1f865d9b000a8b89c7aefd275c22b413e6f84d38.pdf      ICLR       2017
# 7623  /pdf/4d96ecd11daa9de9a3f185eb5df2cec042f0c7c9.pdf      ICLR       2017
# 7624             https://arxiv.org/pdf/1610.09585v1.pdf      ICLR       2017
# 7625  /pdf/2caad8143d962dd837f7ea1a54b95aba2b12993a.pdf      ICLR       2017
# 7626  /pdf/2c4a40726fd9c87df0bea025fc4b56729323c30b.pdf      ICLR       2017
#
#                                                    tldr        forum  \
# 0     We develop sharper generalization bounds for l...  r28GdiQF7vM
# 1     We propose a graph topology  to overcome the d...  o29tNZZqGcN
# 2     We investigate and improve parameter-sharing s...  Wj4ODo0uyCF
# 3     This work proposes an application of reinforce...   _qJXkf347k
# 4     This paper proposes a loss based on discrete M...   LGgdb4TS4Z
# ...                                                 ...          ...
# 7622  fast attention in O(log n); learned sorting al...    BkfiXiUlg
# 7623                                                NaN    SkqMSCHxe
# 7624  We introduce a special GAN architecture that r...    rJXTf9Bxg
# 7625  Adversarial training of neural networks to lea...    S1HEBe_Jl
# 7626  In this paper, we add surprisal as additional ...    S1J0E-71l
#
#       rating_int
# 0       6.000000
# 1       5.000000
# 2       7.750000
# 3       3.000000
# 4       6.500000
# ...          ...
# 7622    4.333333
# 7623    2.666667
# 7624    5.000000
# 7625    5.000000
# 7626    3.333333
#
# [7627 rows x 16 columns]

# %%
df_new = df_submission_score.groupby('conf_year')['rating_int'].mean().reset_index()

# %%
df_new
# Out:
#    conf_year  rating_int
# 0       2017    5.683061
# 1       2018    5.431410
# 2       2019    5.440087
# 3       2020    4.418113
# 4       2021    5.509815

# %%
# Sort the DataFrame by 'conf_year' if necessary to ensure the line is drawn correctly
df_new_sorted = df_new.sort_values(by='conf_year')

# Create the plot
plt.figure(figsize=(10, 6))

# Scatter plot
plt.scatter(df_new_sorted['conf_year'], df_new_sorted['rating_int'], c='blue', alpha=0.6, edgecolors='w', s=100, label='Ratings')

# Line plot to connect the dots
plt.plot(df_new_sorted['conf_year'], df_new_sorted['rating_int'], color='blue', linewidth=2)

# Add titles and labels
plt.title('Conference Year vs. Rating', fontsize=15)
plt.xlabel('Conference Year', fontsize=12)
plt.ylabel('Rating', fontsize=12)

# Customize the grid
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Brainstorm:
#
# What are some questions for the data that we can look through some suggestions:
# * Number of submissions by year
# * Length of review by year
# * Reviewer confidence by year
# * Topics by year

# %%
df_submission_count = df_submission_score.groupby('conf_year')['forum'].count().reset_index()


# Customize the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df_submission_count['conf_year'], df_submission_count['forum'], c='blue', alpha=0.6, edgecolors='w', s=100)

# Add titles and labels
plt.title('Conference Year vs. Number of Submissions', fontsize=15)
plt.xlabel('Conference Year', fontsize=12)
plt.ylabel('Number of Submissions', fontsize=12)

# Customize the grid
plt.grid(True, linestyle='--', alpha=0.7)

# Add annotations or text if needed (example: highlighting a specific point)
# plt.text(x, y, 'Label', fontsize=12)

# Show the plot
plt.show()
