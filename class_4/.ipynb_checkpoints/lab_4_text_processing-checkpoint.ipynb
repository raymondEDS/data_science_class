# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from wordcloud import WordCloud
# Out:
# /opt/anaconda3/envs/nlp/lib/python3.10/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df_reviews = pd.read_csv('../data/reviews.csv')
df_submissions = pd.read_csv('../data/Submissions.csv')
df_dec = pd.read_csv('../data/decision.csv')
df_keyword = pd.read_csv('../data/submission_keyword.csv')

# %%
df_submissions.head()
# Out:
#             id      original        tcdate        tmdate  number  \
# 0  r28GdiQF7vM   YaMZTQ7VXt2  1.601310e+12  1.635170e+12     546
# 1  o29tNZZqGcN  w4nLEWLcq9ZN  1.601310e+12  1.633020e+12    1000
# 2  Wj4ODo0uyCF   EGD9_RwnpMs  1.601310e+12  1.632760e+12    3265
# 3   _qJXkf347k    7LgLMxopN9  1.601310e+12  1.632380e+12    1892
# 4   LGgdb4TS4Z    c4RxVOgHI1  1.601310e+12  1.632240e+12    2141
#
#                                                title  \
# 0  Sharper Generalization Bounds for Learning wit...
# 1  Bridging Graph Network to Lifelong Learning wi...
# 2  Share or Not? Learning to Schedule Language-Sp...
# 3  Reinforcement Learning Based Asymmetrical DNN ...
# 4  Topology-Aware Segmentation Using Discrete Mor...
#
#                                            authorids  \
# 0                  ["~Yunwen_Lei1", "~Yiming_Ying1"]
# 1  ["~Chen_Wang2", "~Yuheng_Qiu1", "~Sebastian_Sc...
# 2  ["~Biao_Zhang2", "~Ankur_Bapna1", "~Rico_Sennr...
# 3  ["~Brijraj_Singh1", "ya.jain@samsung.com", "~M...
# 4  ["~Xiaoling_Hu1", "~Yusu_Wang1", "~Li_Fuxin1",...
#
#                                              authors  \
# 0                      ["Yunwen Lei", "Yiming Ying"]
# 1   ["Chen Wang", "Yuheng Qiu", "Sebastian Scherer"]
# 2  ["Biao Zhang", "Ankur Bapna", "Rico Sennrich",...
# 3  ["Brijraj Singh", "Yash Jain", "Mayukh Das", "...
# 4  ["Xiaoling Hu", "Yusu Wang", "Li Fuxin", "Dimi...
#
#                                             keywords  \
# 0   ["generalization bounds", "non-convex learning"]
# 1     ["Graph Neural Network", "Continual Learning"]
# 2  ["language-specific modeling", "conditional co...
# 3                ["DNN Compression", "Loading time"]
# 4  ["Topology", "Morse theory", "Image segmentati...
#
#                                             abstract  \
# 0  Stochastic optimization has become the workhor...
# 1  Graph neural networks (GNN) are powerful model...
# 2  Using a mix of shared and language-specific (L...
# 3  Latency of DNN (Deep Neural Network) based pre...
# 4  In the segmentation of fine-scale structures f...
#
#                                                  pdf conf_name  conf_year  \
# 0  /pdf/43ac8e3a506c7ad54162957c4698675f659e050a.pdf      ICLR       2021
# 1  /pdf/dd7ff523aa1bd5d49e10f887e350de2ee909023a.pdf      ICLR       2021
# 2  /pdf/daf5088c43f0425f9ab145f2bb0b1db43092147f.pdf      ICLR       2021
# 3  https://openreview.net/references/pdf?id=x1Fun...      ICLR       2021
# 4  /pdf/e328a81d734d6f9eb2808b309985c8aeffb1b27b.pdf      ICLR       2021
#
#                                                 tldr
# 0  We develop sharper generalization bounds for l...
# 1  We propose a graph topology  to overcome the d...
# 2  We investigate and improve parameter-sharing s...
# 3  This work proposes an application of reinforce...
# 4  This paper proposes a loss based on discrete M...

# %%
df_submissions.head()

# %%
df_reviews.head()
# Out:
#             id  number        forum      replyto  \
# 0  kOJs5_dKXyW       4  tGZu6DlbreV  tGZu6DlbreV
# 1  kbedPNPDFwa       1  uKhGRvM8QNH  uKhGRvM8QNH
# 2  zgzRcwaItum       2   IrM64DGB21   IrM64DGB21
# 3  ZJ_1Qi4LbUb       2  ww-7bdU6GA9  ww-7bdU6GA9
# 4   Bbp-JccEu-       3  j0uePNuoBho  j0uePNuoBho
#
#                                                title  \
# 0  Review of "RNNLogic: Learning Logic Rules for ...
# 1  This paper proposes two knowledge distillation...
# 2  Needs to rephrase claims and design experiment...
# 3  Paper that has good contributions for analyzin...
# 4      Review of the paper Learned Threshold Pruning
#
#                                               review  rating_int  \
# 0  There is a lot of recent work on link-predicti...           6
# 1  Pros:\n\n- The different attention techniques ...           6
# 2  Overview of the paper: \nThis paper studies th...           5
# 3  ## Summary\nThe authors propose a near minimax...           6
# 4  The paper proposed a new method to prune a neu...           6
#
#    confidence_int conf_name
# 0             4.0  ICLR2021
# 1             4.0  ICLR2021
# 2             4.0  ICLR2021
# 3             3.0  ICLR2021
# 4             4.0  ICLR2021

# %%
df_reviews['review'][1]
# Out:
# 'Pros:\n\n- The different attention techniques seem to consistently improve object detectors across different models. \n- The ablation studies are important in showing the advantage and impact of each proposed module. \n- Please clarify if the student models start from random weights or are initialized after the teacher training. In this regard to what extend is the approach is transferable to students with random weights?\n\nCons:\n\n- The authors only show results when training a network of the same structure with the added modules, in an attempt to boost accuracy. However, an important use of knowledge of knowledge distillation is to train smaller models, and such results are missing from the paper. Overall, the results in the paper somewhat justify the "accurate" part of the title but not the "efficient".\n\n- The importance of high AP is a bit overstated. It is important to demonstrate the different behavior between classification and detection networks, however, the same improvement is observed irrespective of the teacher AP performance. \n\n- The structure of the paper can be improved. The related work section for example can be moved earlier in the paper to give the bigger picture and the position of this work with respect to the literature. \n\n- For a more complete comparison YOLO and SSD networks should be included.\n\n- In the qualitative analysis observation (ii) states that the proposed methods leads to single box per object compared to the baselines. In this case do the baselines use non-maximum suppression? This is a standard post processing technique that alleviates this problem. No explanation is given on why the proposed method leads to this behavior.\n\nThe authors have made clear some of my concerns and made revisions accordingly. Thus I am in a position now to recommend this paper, thus I update my initial recommendation from 5 to 6.'

# %%
df_keyword.head()
# Out:
#   submission_id          primary_keyword       secondary_keyword
# 0   --gvHfE3Xf5   reinforcement learning           meta-learning
# 1    --rcOeCKRh        transfer learning        object detection
# 2    -0LuSWi6j4  variational autoencoder  deep generative models
# 3   -29uFS4FiDZ          word embeddings                   other
# 4   -2FCwDKRREu  representation learning                   other

# %%
#get the average review score
df_average_review_score = df_reviews.groupby('forum')['rating_int'].mean().reset_index()
df_average_review_score
# Out:
#             forum  rating_int
# 0          #NAME?    5.479730
# 1     -2FCwDKRREu    7.666667
# 2     -5VpoDCExrU    4.750000
# 3     -5W5OBfFlwX    4.000000
# 4      -6vS_4Kfz0    6.250000
# ...           ...         ...
# 7587  zsKWh2pRSBK    4.750000
# 7588  zspml_qcldq    4.000000
# 7589  ztMLindFLWR    5.800000
# 7590  zv-typ1gPxA    7.000000
# 7591  zx_uX-BO7CH    6.500000
#
# [7592 rows x 2 columns]

# %% [markdown]
# # Looking at Review Length and Score & Decision

# %%
#Step 1 - Combine Review DF and Decision DF

df_rev_dec = pd.merge(df_reviews, df_dec, left_on='forum', right_on='forum', how = 'inner')[['review','decision','conf_name_y','rating_int','forum']]

df_rev_dec.head()
# Out:
#                                               review         decision  \
# 0  There is a lot of recent work on link-predicti...  Accept (Poster)
# 1  In this paper, the author proposes RNNLogic fo...  Accept (Poster)
# 2  This paper focuses on learning logic rules via...  Accept (Poster)
# 3  In this work, the authors illustrate an approa...  Accept (Poster)
# 4  Pros:\n\n- The different attention techniques ...  Accept (Poster)
#
#   conf_name_y  rating_int        forum
# 0    ICLR2021           6  tGZu6DlbreV
# 1    ICLR2021           7  tGZu6DlbreV
# 2    ICLR2021           6  tGZu6DlbreV
# 3    ICLR2021           8  tGZu6DlbreV
# 4    ICLR2021           6  uKhGRvM8QNH

# %% [markdown]
# ## Text Cleaning or Word Normalization

# %%
#case folding

df_rev_dec['review'] = df_rev_dec['review'].str.lower()

# %%
df_rev_dec
# Out:
#                                                   review         decision  \
# 0      there is a lot of recent work on link-predicti...  Accept (Poster)
# 1      in this paper, the author proposes rnnlogic fo...  Accept (Poster)
# 2      this paper focuses on learning logic rules via...  Accept (Poster)
# 3      in this work, the authors illustrate an approa...  Accept (Poster)
# 4      pros:\n\n- the different attention techniques ...  Accept (Poster)
# ...                                                  ...              ...
# 25163  the author proposes the use of low-rank matrix...           Reject
# 25164  the paper proposes a low-rank version of pass-...           Reject
# 25165  the authors study the use of low-rank approxim...           Reject
# 25166  ​there have been numerous works ​on learning f...           Reject
# 25167  this submission proposes a letter-level decode...           Reject
#
#       conf_name_y  rating_int        forum
# 0        ICLR2021           6  tGZu6DlbreV
# 1        ICLR2021           7  tGZu6DlbreV
# 2        ICLR2021           6  tGZu6DlbreV
# 3        ICLR2021           8  tGZu6DlbreV
# 4        ICLR2021           6  uKhGRvM8QNH
# ...           ...         ...          ...
# 25163    ICLR2017           4    rkaRFYcgl
# 25164    ICLR2017           5    rkaRFYcgl
# 25165    ICLR2017           6    rkaRFYcgl
# 25166    ICLR2017           6    BkUDvt5gg
# 25167    ICLR2017           7    BkUDvt5gg
#
# [25168 rows x 5 columns]

# %%
df_rev_dec['decision'].unique()
# Out:
# array(['Accept (Poster)', 'Reject', 'Accept (Spotlight)', 'Accept (Oral)',
#        'Accept (Talk)', 'Invite to Workshop Track'], dtype=object)

# %%
#clean up decision text

def clean_up_decision(text):
    if text in ['Accept (Poster)','Accept (Spotlight)', 'Accept (Oral)','Accept (Talk)']:
        return 'Accept'
    else:
        return text

    
df_rev_dec['decision_clean'] = df_rev_dec['decision'].apply(clean_up_decision)

# %%
df_rev_dec['decision_clean']
# Out:
# array(['Accept', 'Reject', 'Invite to Workshop Track'], dtype=object)

# %% [markdown]
# ## Number of Sentences Per Review

# %%
sent_tokenize(df_reviews['review'][1])

# %%
def sentence_count(text):
    return len(sent_tokenize(text))


df_rev_dec['sent_count'] = df_rev_dec['review'].apply(sentence_count)

# %%
df_rev_dec.head()

# %%
ax = sns.histplot(data=df_rev_dec, x='sent_count',
                  y='rating_int',
                  hue='decision_clean',
                kde=True, 
                  log_scale=(True,False),
                 legend=True)

# Set axis labels
ax.set(xlabel='Submission Length (# Sentences)', ylabel='Review Rating')

# Move the legend outside the plot
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Number of Tokens Per Review
#
# - Text Preprocessing: It converts raw text data into a structured format that can be easily processed by NLP algorithms and models.
#
#
# - Feature Extraction: Tokens serve as features or inputs for various NLP tasks, such as text classification, sentiment analysis, and machine translation.
#
#
# - Handling Out-of-Vocabulary (OOV) Words: Certain tokenization techniques, like subword tokenization, can handle previously unseen or rare words by breaking them down into smaller, meaningful units.
#
#
# - Language Understanding: Tokenization helps NLP models understand the structure and meaning of text by separating it into meaningful units.

# %%
# Removing punctuation
df_rev_dec['clean_review_word'] = df_rev_dec['review'].str.translate(str.maketrans('', '', string.punctuation))

df_rev_dec['clean_review_word']

# %%
word_tokenize(df_rev_dec['clean_review_word'][0])

# %%
# Tokenizing the text
df_rev_dec['tokens'] = df_rev_dec['clean_review_word'].apply(word_tokenize)

# %%
df_rev_dec['tokens'][2]

# %%
stop_words = set(stopwords.words('english'))

stop_words

# %%
stop_words = set(stopwords.words('english'))
df_rev_dec['tokens'] = df_rev_dec['tokens'].apply(lambda x: [word for word in x if word not in stop_words])

df_rev_dec['tokens']

# %%
df_rev_dec['tokens_counts'] = df_rev_dec['tokens'].apply(len)

# %%
# Removing punctuation
df_rev_dec['clean_review_word'] = df_rev_dec['review'].str.translate(str.maketrans('', '', string.punctuation))


# Tokenizing the text
df_rev_dec['tokens'] = df_rev_dec['clean_review_word'].apply(word_tokenize)


# Removing stop words
stop_words = set(stopwords.words('english'))
df_rev_dec['tokens'] = df_rev_dec['tokens'].apply(lambda x: [word for word in x if word not in stop_words])
df_rev_dec['tokens_counts'] = df_rev_dec['tokens'].apply(len)

# %%
df_rev_dec['tokens_counts']

# %%
ax = sns.histplot(data=df_rev_dec, x='tokens_counts',
                  y='rating_int',
                  hue='decision_clean',
                kde=True, 
                  log_scale=(True,False),
                 legend=True)

# Set axis labels
ax.set(xlabel='Submission Length (# Tokens)', ylabel='Review Rating')

# Move the legend outside the plot
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Average Token and Sentence Count

# %%
df_rev_dec_ave = df_rev_dec.groupby(['forum','decision_clean'])[['rating_int','tokens_counts','sent_count']].mean().reset_index()

# %%
ax = sns.histplot(data=df_rev_dec_ave, x='tokens_counts',
                  y='rating_int',
                  hue='decision_clean',
                kde=True, 
                  log_scale=(True,False),
                 legend=True)

# Set axis labels
ax.set(xlabel='Submission Length (# Tokens)', ylabel='Review Rating')

# Move the legend outside the plot
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

plt.tight_layout()
plt.show()

# %%
ax = sns.histplot(data=df_rev_dec_ave, x='sent_count',
                  y='rating_int',
                  hue='decision_clean',
                kde=True, 
                  log_scale=(True,False),
                 legend=True)

# Set axis labels
ax.set(xlabel='Submission Length (# Sentences)', ylabel='Review Rating')

# Move the legend outside the plot
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

plt.tight_layout()
plt.show()

# %%
# Concatenate text data
text = ' '.join(df_rev_dec['clean_review_word'])

# Generate word cloud
wordcloud = WordCloud().generate(text)

# Display word cloud
plt.figure(figsize=(8, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Concatenate text data
text = ' '.join(df_keyword['primary_keyword'])

# Generate word cloud
wordcloud = WordCloud().generate(text)

# Display word cloud
plt.figure(figsize=(8, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Concatenate text data
text = ' '.join(df_submissions['abstract'])

# Generate word cloud
wordcloud = WordCloud().generate(text)

# Display word cloud
plt.figure(figsize=(8, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
