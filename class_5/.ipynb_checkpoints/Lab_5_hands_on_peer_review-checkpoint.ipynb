# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
from nltk.tokenize import word_tokenize


import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# special matplotlib argument for improved plots
from matplotlib import rcParams

# %%
df_reviews = pd.read_csv('../data/reviews.csv')
df_submissions = pd.read_csv('../data/Submissions.csv')
df_dec = pd.read_csv('../data/decision.csv')
df_keyword = pd.read_csv('../data/submission_keyword.csv')

# %%
df_reviews[['rating_int','confidence_int','review','forum']]
# Out:
#        rating_int  confidence_int  \
# 0               6             4.0
# 1               6             4.0
# 2               5             4.0
# 3               6             3.0
# 4               6             4.0
# ...           ...             ...
# 25311           8             3.0
# 25312           3             5.0
# 25313           6             4.0
# 25314           5             4.0
# 25315           8             5.0
#
#                                                   review        forum
# 0      There is a lot of recent work on link-predicti...  tGZu6DlbreV
# 1      Pros:\n\n- The different attention techniques ...  uKhGRvM8QNH
# 2      Overview of the paper: \nThis paper studies th...   IrM64DGB21
# 3      ## Summary\nThe authors propose a near minimax...  ww-7bdU6GA9
# 4      The paper proposed a new method to prune a neu...  j0uePNuoBho
# ...                                                  ...          ...
# 25311  This paper introduces a 'GPU-friendly' variant...    r1VGvBcxl
# 25312  This paper is relatively difficult to parse. M...    rkFd2P5gl
# 25313  This paper is technically sound. It highlights...    SyVVJ85lg
# 25314  A few issues with this paper:\n1- I find findi...    Bygq-H9eg
# 25315  This paper studies in depth the idea of quanti...    S1_pAu9xl
#
# [25316 rows x 4 columns]

# %%
df_submissions[['abstract','id','conf_year']]
# Out:
#                                                abstract           id  \
# 0     Stochastic optimization has become the workhor...  r28GdiQF7vM
# 1     Graph neural networks (GNN) are powerful model...  o29tNZZqGcN
# 2     Using a mix of shared and language-specific (L...  Wj4ODo0uyCF
# 3     Latency of DNN (Deep Neural Network) based pre...   _qJXkf347k
# 4     In the segmentation of fine-scale structures f...   LGgdb4TS4Z
# ...                                                 ...          ...
# 7623  In this paper, we propose and investigate a no...    BkfiXiUlg
# 7624  We propose a learning method to quantify human...    SkqMSCHxe
# 7625  Synthesizing high resolution photorealistic im...    rJXTf9Bxg
# 7626  We ask whether neural networks can learn to us...    S1HEBe_Jl
# 7627  Recurrent neural nets are widely used for pred...    S1J0E-71l
#
#       conf_year
# 0          2021
# 1          2021
# 2          2021
# 3          2021
# 4          2021
# ...         ...
# 7623       2017
# 7624       2017
# 7625       2017
# 7626       2017
# 7627       2017
#
# [7628 rows x 3 columns]

# %%
df_rs = pd.merge(df_reviews[['rating_int','confidence_int','review','forum']], df_submissions[['abstract','id','conf_year']], left_on='forum', right_on='id', how = 'inner')

# %%
df_rs['review'] = df_rs['review'].str.lower()
df_rs['abstract'] = df_rs['abstract'].str.lower()

# %%
df_rs['review_tokens'] = df_rs['review'].apply(word_tokenize)

# %%
df_rs['review_num_tokens'] = df_rs['review_tokens'].apply(len)

# %%
df_rs_average = df_rs.groupby(['forum'])[['rating_int','review_num_tokens','confidence_int']].mean().reset_index()

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df_rs_average['confidence_int'], df_rs_average['rating_int'], alpha=0.6, cmap='viridis', edgecolor='w', linewidth=0.5)


# Add titles and labels
plt.title('Average Review Rating by Reviewer Confidence')
plt.xlabel('Reviewer Confidence')
plt.ylabel('Rating')

# Customize ticks
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=12)

# Add grid
plt.grid(True, linestyle='--', alpha=0.7)


# Show plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/v9/8whxr3fd1mv_pwkjh0kn920m0000gn/T/ipykernel_16315/2078969568.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = plt.scatter(df_rs_average['confidence_int'], df_rs_average['rating_int'], alpha=0.6, cmap='viridis', edgecolor='w', linewidth=0.5)

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create a regression plot
plt.figure(figsize=(10, 6))
sns.regplot(y="rating_int", x="confidence_int", data=df_rs_average, fit_reg=True, 
            scatter_kws={'s': 50, 'alpha': 0.6, 'color': 'b'}, 
            line_kws={'color': 'red', 'linewidth': 2})

# Customize the plot with titles and labels
plt.title('Title', fontsize=20)
plt.xlabel('confidence_int', fontsize=15)
plt.ylabel('rating_int', fontsize=15)

# Customize the ticks on the axes
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Show grid
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols


m = ols('rating_int ~ confidence_int',df_rs_average).fit()
m.summary()
# Out:
# /opt/anaconda3/envs/nlp/lib/python3.10/site-packages/patsy/util.py:672: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return _pandas_is_categorical_dtype(dt)
# /opt/anaconda3/envs/nlp/lib/python3.10/site-packages/patsy/util.py:672: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return _pandas_is_categorical_dtype(dt)
# /opt/anaconda3/envs/nlp/lib/python3.10/site-packages/patsy/util.py:672: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return _pandas_is_categorical_dtype(dt)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             rating_int   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     153.8
# Date:                Thu, 27 Jun 2024   Prob (F-statistic):           7.76e-35
# Time:                        23:42:25   Log-Likelihood:                -8181.6
# No. Observations:                5379   AIC:                         1.637e+04
# Df Residuals:                    5377   BIC:                         1.638e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          6.8855      0.113     60.819      0.000       6.664       7.107
# confidence_int    -0.3713      0.030    -12.400      0.000      -0.430      -0.313
# ==============================================================================
# Omnibus:                       16.185   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               13.384
# Skew:                          -0.048   Prob(JB):                      0.00124
# Kurtosis:                       2.775   Cond. No.                         30.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_rs_average.columns
# Out:
# Index(['forum', 'rating_int', 'review_num_tokens', 'confidence_int'], dtype='object')

# %%
m = ols('rating_int ~ review_num_tokens + confidence_int',df_rs_average).fit()
m.summary()
# Out:
# /opt/anaconda3/envs/nlp/lib/python3.10/site-packages/patsy/util.py:672: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return _pandas_is_categorical_dtype(dt)
# /opt/anaconda3/envs/nlp/lib/python3.10/site-packages/patsy/util.py:672: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return _pandas_is_categorical_dtype(dt)
# /opt/anaconda3/envs/nlp/lib/python3.10/site-packages/patsy/util.py:672: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return _pandas_is_categorical_dtype(dt)
# /opt/anaconda3/envs/nlp/lib/python3.10/site-packages/patsy/util.py:672: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return _pandas_is_categorical_dtype(dt)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             rating_int   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     76.90
# Date:                Thu, 27 Jun 2024   Prob (F-statistic):           1.18e-33
# Time:                        23:44:45   Log-Likelihood:                -8181.6
# No. Observations:                5379   AIC:                         1.637e+04
# Df Residuals:                    5376   BIC:                         1.639e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             6.8924      0.117     58.929      0.000       6.663       7.122
# review_num_tokens -1.842e-05   7.73e-05     -0.238      0.812      -0.000       0.000
# confidence_int       -0.3708      0.030    -12.340      0.000      -0.430      -0.312
# ==============================================================================
# Omnibus:                       16.217   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               13.437
# Skew:                          -0.049   Prob(JB):                      0.00121
# Kurtosis:                       2.775   Cond. No.                     4.26e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_dec
# Out:
#                 id         tcdate         tmdate  number        forum  \
# 0       0zV62G_Z4s  1610040357457  1611063503220       1  meG3o0ttiAD
# 1      SZvFCZvTsoS  1610040498377  1610992686336       1  AJY3fGPF1DC
# 2       -9zBJ8kapV  1610040388799  1610734729796       1  _O9YLet0wvN
# 3       dswNkjMSvK  1610040389095  1610717627789       1   WoLQsYU8aZ
# 4      hHfc3BD1vIb  1610040488610  1610618696830       1  Sc8cY4Jpi3s
# ...            ...            ...            ...     ...          ...
# 10300  iCMbtNSRp3s  1642696832494  1642696832494       1  j-63FSNcO5a
# 10301  ZjiBIEPyMOn  1642696832492  1642696832492       1  AjGC97Aofee
# 10302  -bEai7YVHEi  1642696832460  1642696832460       1  BnQhMqDfcKG
# 10303  RKQzOhYsYd5  1642696832458  1642696832458       1  JLbXkHkLCG6
# 10304  xBFxR-EPLhR  1642696832456  1642696832456       1  7l1IjZVddDW
#
#            replyto           title            decision  \
# 0      meG3o0ttiAD  Final Decision              Reject
# 1      AJY3fGPF1DC  Final Decision              Reject
# 2      _O9YLet0wvN  Final Decision              Reject
# 3       WoLQsYU8aZ  Final Decision              Reject
# 4      Sc8cY4Jpi3s  Final Decision              Reject
# ...            ...             ...                 ...
# 10300  j-63FSNcO5a  Paper Decision     Accept (Poster)
# 10301  AjGC97Aofee  Paper Decision     Accept (Poster)
# 10302  BnQhMqDfcKG  Paper Decision  Accept (Spotlight)
# 10303  JLbXkHkLCG6  Paper Decision              Reject
# 10304  7l1IjZVddDW  Paper Decision  Accept (Spotlight)
#
#                                                  comment conf_name confidence
# 0      This paper introduces two new quantum neural n...  ICLR2021        NaN
# 1      This paper considers the problem of identifica...  ICLR2021        NaN
# 2      The reviewers have ranked this paper as border...  ICLR2021        NaN
# 3      This paper represents the PettingZoo library o...  ICLR2021        NaN
# 4      Dear authors,\n\nI like to topic of your paper...  ICLR2021        NaN
# ...                                                  ...       ...        ...
# 10300  The paper proposes a framework, named Disentag...  ICLR2022        NaN
# 10301  This paper receives positive reviews. The auth...  ICLR2022        NaN
# 10302  This paper introduced a probabilistic extensio...  ICLR2022        NaN
# 10303  Learning policies from video demonstrations al...  ICLR2022        NaN
# 10304  This paper received 4 quality reviews. The reb...  ICLR2022        NaN
#
# [10305 rows x 11 columns]

# %%
df_combined_model = pd.merge(df_rs, df_dec, left_on='forum', right_on='forum', how = 'inner').head()

df_combined_model.to_csv('df_combined_model.csv')

# %%
df_combined_model
# Out:
#    rating_int  confidence_int  \
# 0           6             4.0
# 1           7             4.0
# 2           6             2.0
# 3           8             1.0
# 4           6             4.0
#
#                                               review        forum  \
# 0  there is a lot of recent work on link-predicti...  tGZu6DlbreV
# 1  in this paper, the author proposes rnnlogic fo...  tGZu6DlbreV
# 2  this paper focuses on learning logic rules via...  tGZu6DlbreV
# 3  in this work, the authors illustrate an approa...  tGZu6DlbreV
# 4  pros:\n\n- the different attention techniques ...  uKhGRvM8QNH
#
#                                             abstract         id_x  conf_year  \
# 0  this paper studies learning logic rules for re...  tGZu6DlbreV       2021
# 1  this paper studies learning logic rules for re...  tGZu6DlbreV       2021
# 2  this paper studies learning logic rules for re...  tGZu6DlbreV       2021
# 3  this paper studies learning logic rules for re...  tGZu6DlbreV       2021
# 4  knowledge distillation, in which a student mod...  uKhGRvM8QNH       2021
#
#                                        review_tokens  review_num_tokens  \
# 0  [there, is, a, lot, of, recent, work, on, link...               1537
# 1  [in, this, paper, ,, the, author, proposes, rn...                722
# 2  [this, paper, focuses, on, learning, logic, ru...                236
# 3  [in, this, work, ,, the, authors, illustrate, ...                121
# 4  [pros, :, -, the, different, attention, techni...                338
#
#           id_y         tcdate         tmdate  number      replyto  \
# 0  uVb3Ow-12JH  1610045694102  1610474017438       1  tGZu6DlbreV
# 1  uVb3Ow-12JH  1610045694102  1610474017438       1  tGZu6DlbreV
# 2  uVb3Ow-12JH  1610045694102  1610474017438       1  tGZu6DlbreV
# 3  uVb3Ow-12JH  1610045694102  1610474017438       1  tGZu6DlbreV
# 4   a8RiFt2IlY  1610040503192  1610474110215       1  uKhGRvM8QNH
#
#             title         decision  \
# 0  Final Decision  Accept (Poster)
# 1  Final Decision  Accept (Poster)
# 2  Final Decision  Accept (Poster)
# 3  Final Decision  Accept (Poster)
# 4  Final Decision  Accept (Poster)
#
#                                              comment conf_name confidence
# 0  There is a consensus among the reviewers that ...  ICLR2021        NaN
# 1  There is a consensus among the reviewers that ...  ICLR2021        NaN
# 2  There is a consensus among the reviewers that ...  ICLR2021        NaN
# 3  There is a consensus among the reviewers that ...  ICLR2021        NaN
# 4  After the rebuttal stage, all reviewers lean p...  ICLR2021        NaN

# %% [markdown]
# 1) Do the tokenization for both abstract and review including removing the stop words
#
# 2) Run an analysis on what relationship we would like to analyze with linear regression given the features we have built
#
# 3) Run the regression and interpret the results

# %% [markdown]
# # Potential Relationships:
#
# 1) Reviewer score and Review Confidence
# 2) Review Length and Review Score
# 3) Review Length and Review Confidence
#
# 3) Review score + Conference Year ~ Accept/Reject
# 4) Conference Year ~ Review Confidence
