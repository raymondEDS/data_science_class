# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
from nltk.tokenize import word_tokenize
import statsmodels.api as sm
from statsmodels.formula.api import ols

import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# special matplotlib argument for improved plots
from matplotlib import rcParams
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def regression_graph(y,x,df,title):

    # Set the aesthetic style of the plots
    sns.set(style="whitegrid")

    # Create a regression plot
    plt.figure(figsize=(10, 6))
    sns.regplot(y=y, x=x, data=df, fit_reg=True, 
                scatter_kws={'s': 50, 'alpha': 0.6, 'color': 'b'}, 
                line_kws={'color': 'red', 'linewidth': 2})

    # Customize the plot with titles and labels
    plt.title(title, fontsize=20)

    # Customize the ticks on the axes
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)

    # Show grid
    plt.grid(True, linestyle='--', alpha=0.7)

    # Show the plot
    plt.show()

# %%
df_reviews = pd.read_csv('../data/reviews.csv')
df_submissions = pd.read_csv('../data/Submissions.csv')
df_dec = pd.read_csv('../data/decision.csv')
df_keyword = pd.read_csv('../data/submission_keyword.csv')

df_rs = pd.merge(df_reviews[['rating_int','confidence_int','review','forum']], df_submissions[['abstract','id','conf_year']], left_on='forum', right_on='id', how = 'inner')
df_rs['review'] = df_rs['review'].str.lower()
df_rs['abstract'] = df_rs['abstract'].str.lower()
df_rs['review_tokens'] = df_rs['review'].apply(word_tokenize)
df_rs['review_num_tokens'] = df_rs['review_tokens'].apply(len)

df_data = pd.merge(df_rs, df_dec, left_on='forum', right_on='forum', how = 'inner').drop([
                                                         'id_x',
                                                         'id_y',
                                                         'tcdate',
                                                         'tmdate',
                                                         'number',
                                                         'confidence'],axis = 1)

df_data
# Out:
#        rating_int  confidence_int  \
# 0               6             4.0
# 1               6             4.0
# 2               5             4.0
# 3               6             3.0
# 4               6             4.0
# ...           ...             ...
# 25163           8             3.0
# 25164           3             5.0
# 25165           6             4.0
# 25166           5             4.0
# 25167           8             5.0
#
#                                                   review        forum  \
# 0      there is a lot of recent work on link-predicti...  tGZu6DlbreV
# 1      pros:\n\n- the different attention techniques ...  uKhGRvM8QNH
# 2      overview of the paper: \nthis paper studies th...   IrM64DGB21
# 3      ## summary\nthe authors propose a near minimax...  ww-7bdU6GA9
# 4      the paper proposed a new method to prune a neu...  j0uePNuoBho
# ...                                                  ...          ...
# 25163  this paper introduces a 'gpu-friendly' variant...    r1VGvBcxl
# 25164  this paper is relatively difficult to parse. m...    rkFd2P5gl
# 25165  this paper is technically sound. it highlights...    SyVVJ85lg
# 25166  a few issues with this paper:\n1- i find findi...    Bygq-H9eg
# 25167  this paper studies in depth the idea of quanti...    S1_pAu9xl
#
#                                                 abstract  conf_year  \
# 0      this paper studies learning logic rules for re...       2021
# 1      knowledge distillation, in which a student mod...       2021
# 2      model-based planning is often thought to be ne...       2021
# 3      transfer learning is an essential technique wh...       2021
# 4      this paper presents a novel differentiable met...       2021
# ...                                                  ...        ...
# 25163  we introduce a hybrid cpu/gpu version of the a...       2017
# 25164  in this paper, we present multiple approaches ...       2017
# 25165  although various scalable deep learning softwa...       2017
# 25166  since the emergence of deep neural networks (d...       2017
# 25167  deep neural networks are widely used in machin...       2017
#
#                                            review_tokens  review_num_tokens  \
# 0      [there, is, a, lot, of, recent, work, on, link...               1537
# 1      [pros, :, -, the, different, attention, techni...                338
# 2      [overview, of, the, paper, :, this, paper, stu...                793
# 3      [#, #, summary, the, authors, propose, a, near...                144
# 4      [the, paper, proposed, a, new, method, to, pru...                207
# ...                                                  ...                ...
# 25163  [this, paper, introduces, a, 'gpu-friendly, ',...                278
# 25164  [this, paper, is, relatively, difficult, to, p...                178
# 25165  [this, paper, is, technically, sound, ., it, h...                188
# 25166  [a, few, issues, with, this, paper, :, 1-, i, ...                210
# 25167  [this, paper, studies, in, depth, the, idea, o...                182
#
#            replyto                          title         decision  \
# 0      tGZu6DlbreV                 Final Decision  Accept (Poster)
# 1      uKhGRvM8QNH                 Final Decision  Accept (Poster)
# 2       IrM64DGB21                 Final Decision  Accept (Poster)
# 3      ww-7bdU6GA9                 Final Decision           Reject
# 4      j0uePNuoBho                 Final Decision           Reject
# ...            ...                            ...              ...
# 25163    r1VGvBcxl  ICLR committee final decision  Accept (Poster)
# 25164    rkFd2P5gl  ICLR committee final decision           Reject
# 25165    SyVVJ85lg  ICLR committee final decision  Accept (Poster)
# 25166    Bygq-H9eg  ICLR committee final decision           Reject
# 25167    S1_pAu9xl  ICLR committee final decision  Accept (Poster)
#
#                                                  comment conf_name
# 0      There is a consensus among the reviewers that ...  ICLR2021
# 1      After the rebuttal stage, all reviewers lean p...  ICLR2021
# 2      The reviewers appreciated the author replies, ...  ICLR2021
# 3       \nThis paper derives estimators and minimax g...  ICLR2021
# 4      This paper proposes a method for differentiabl...  ICLR2021
# ...                                                  ...       ...
# 25163  This paper suggests modifications to A3C - mai...  ICLR2017
# 25164  A summary of strengths and weaknesses brought ...  ICLR2017
# 25165  The reviewers were consistent in their praise ...  ICLR2017
# 25166  The paper presents an evaluation of off-the-sh...  ICLR2017
# 25167  The paper describes a method for training neur...  ICLR2017
#
# [25168 rows x 13 columns]

# %%
df_data = pd.merge(df_rs, df_dec, left_on='forum', right_on='forum', how = 'inner').drop([
                                                         'id_x',
                                                         'id_y',
                                                         'tcdate',
                                                         'tmdate',
                                                         'number',
                                                         'confidence'],axis = 1)

df_data
# Out:
#        rating_int  confidence_int  \
# 0               6             4.0
# 1               6             4.0
# 2               5             4.0
# 3               6             3.0
# 4               6             4.0
# ...           ...             ...
# 25163           8             3.0
# 25164           3             5.0
# 25165           6             4.0
# 25166           5             4.0
# 25167           8             5.0
#
#                                                   review        forum  \
# 0      there is a lot of recent work on link-predicti...  tGZu6DlbreV
# 1      pros:\n\n- the different attention techniques ...  uKhGRvM8QNH
# 2      overview of the paper: \nthis paper studies th...   IrM64DGB21
# 3      ## summary\nthe authors propose a near minimax...  ww-7bdU6GA9
# 4      the paper proposed a new method to prune a neu...  j0uePNuoBho
# ...                                                  ...          ...
# 25163  this paper introduces a 'gpu-friendly' variant...    r1VGvBcxl
# 25164  this paper is relatively difficult to parse. m...    rkFd2P5gl
# 25165  this paper is technically sound. it highlights...    SyVVJ85lg
# 25166  a few issues with this paper:\n1- i find findi...    Bygq-H9eg
# 25167  this paper studies in depth the idea of quanti...    S1_pAu9xl
#
#                                                 abstract  conf_year  \
# 0      this paper studies learning logic rules for re...       2021
# 1      knowledge distillation, in which a student mod...       2021
# 2      model-based planning is often thought to be ne...       2021
# 3      transfer learning is an essential technique wh...       2021
# 4      this paper presents a novel differentiable met...       2021
# ...                                                  ...        ...
# 25163  we introduce a hybrid cpu/gpu version of the a...       2017
# 25164  in this paper, we present multiple approaches ...       2017
# 25165  although various scalable deep learning softwa...       2017
# 25166  since the emergence of deep neural networks (d...       2017
# 25167  deep neural networks are widely used in machin...       2017
#
#                                            review_tokens  review_num_tokens  \
# 0      [there, is, a, lot, of, recent, work, on, link...               1537
# 1      [pros, :, -, the, different, attention, techni...                338
# 2      [overview, of, the, paper, :, this, paper, stu...                793
# 3      [#, #, summary, the, authors, propose, a, near...                144
# 4      [the, paper, proposed, a, new, method, to, pru...                207
# ...                                                  ...                ...
# 25163  [this, paper, introduces, a, 'gpu-friendly, ',...                278
# 25164  [this, paper, is, relatively, difficult, to, p...                178
# 25165  [this, paper, is, technically, sound, ., it, h...                188
# 25166  [a, few, issues, with, this, paper, :, 1-, i, ...                210
# 25167  [this, paper, studies, in, depth, the, idea, o...                182
#
#            replyto                          title         decision  \
# 0      tGZu6DlbreV                 Final Decision  Accept (Poster)
# 1      uKhGRvM8QNH                 Final Decision  Accept (Poster)
# 2       IrM64DGB21                 Final Decision  Accept (Poster)
# 3      ww-7bdU6GA9                 Final Decision           Reject
# 4      j0uePNuoBho                 Final Decision           Reject
# ...            ...                            ...              ...
# 25163    r1VGvBcxl  ICLR committee final decision  Accept (Poster)
# 25164    rkFd2P5gl  ICLR committee final decision           Reject
# 25165    SyVVJ85lg  ICLR committee final decision  Accept (Poster)
# 25166    Bygq-H9eg  ICLR committee final decision           Reject
# 25167    S1_pAu9xl  ICLR committee final decision  Accept (Poster)
#
#                                                  comment conf_name
# 0      There is a consensus among the reviewers that ...  ICLR2021
# 1      After the rebuttal stage, all reviewers lean p...  ICLR2021
# 2      The reviewers appreciated the author replies, ...  ICLR2021
# 3       \nThis paper derives estimators and minimax g...  ICLR2021
# 4      This paper proposes a method for differentiabl...  ICLR2021
# ...                                                  ...       ...
# 25163  This paper suggests modifications to A3C - mai...  ICLR2017
# 25164  A summary of strengths and weaknesses brought ...  ICLR2017
# 25165  The reviewers were consistent in their praise ...  ICLR2017
# 25166  The paper presents an evaluation of off-the-sh...  ICLR2017
# 25167  The paper describes a method for training neur...  ICLR2017
#
# [25168 rows x 13 columns]

# %% [markdown]
# # Exploratory data analysis.
#
# Please describe the data set in your paper. How many rows of data? What are the descriptive statics? What does this say about the data?
#
# What rows will you be dropping in order to eliminate NANs?

# %%
df_data.describe()
# Out:
#          rating_int  confidence_int     conf_year  review_num_tokens
# count  25168.000000    18434.000000  25168.000000       25168.000000
# mean       5.207525        3.741944   2019.824499         497.592618
# std        1.760269        0.818314      1.225998         329.277716
# min        1.000000        1.000000   2017.000000           3.000000
# 25%        4.000000        3.000000   2019.000000         280.000000
# 50%        6.000000        4.000000   2020.000000         419.000000
# 75%        6.000000        4.000000   2021.000000         626.000000
# max       10.000000        5.000000   2021.000000        5716.000000

# %% [markdown]
# # Correlation matrix
#
# Use the pandas .corr method to look at potential correlations between variables. Answer the following questions:
#
# 1) What variables are heavily correlated?
# 2) Why do you think they are correlated?
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html

# %%
#write your code here
#hint you may have to use the numeric_only parameter
df_data.corr(numeric_only=True)
# Out:
#                    rating_int  confidence_int  conf_year  review_num_tokens
# rating_int           1.000000       -0.143676  -0.025562          -0.051543
# confidence_int      -0.143676        1.000000  -0.047991           0.144220
# conf_year           -0.025562       -0.047991   1.000000           0.186836
# review_num_tokens   -0.051543        0.144220   0.186836           1.000000

# %% [markdown]
# # Potential research questions:
#
# Given that your paper is about how peer review is meant to preserve fairness in the review process. We will look at the following research questions.
#
# 1) Given that the conference has increase in submissions each year this means there will be more reviewers each year. Does the increase number of reviewers decrease the quality of reviews?
#
# 2) Does reviewer confidence affect review scoring?
#
# 3) What factors affect review outcome?

# %% [markdown]
# # Regression Lab
#
# Investigate the following relationships:
# 1) Reviewer score and Review Confidence
# 2) Review Length and Review Score
# 3) Review Length and Review Confidence
#
# 3) Review score + Conference Year ~ Accept/Reject
# 4) Conference Year ~ Review Confidence

# %%
#example code
m = ols('rating_int ~ confidence_int',df_data).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             rating_int   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     388.5
# Date:                Wed, 03 Jul 2024   Prob (F-statistic):           1.33e-85
# Time:                        16:00:40   Log-Likelihood:                -32995.
# No. Observations:               18434   AIC:                         6.599e+04
# Df Residuals:                   18432   BIC:                         6.601e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          6.4568      0.050    129.232      0.000       6.359       6.555
# confidence_int    -0.2571      0.013    -19.711      0.000      -0.283      -0.232
# ==============================================================================
# Omnibus:                      107.019   Durbin-Watson:                   1.632
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.570
# Skew:                           0.028   Prob(JB):                     2.36e-17
# Kurtosis:                       2.689   Cond. No.                         19.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# your code here
m = ols('review_num_tokens ~ rating_int',df_data).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      review_num_tokens   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     67.04
# Date:                Wed, 03 Jul 2024   Prob (F-statistic):           2.79e-16
# Time:                        16:00:59   Log-Likelihood:            -1.8157e+05
# No. Observations:               25168   AIC:                         3.632e+05
# Df Residuals:                   25166   BIC:                         3.632e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    547.8017      6.473     84.625      0.000     535.114     560.490
# rating_int    -9.6416      1.178     -8.188      0.000     -11.950      -7.333
# ==============================================================================
# Omnibus:                    15300.910   Durbin-Watson:                   1.708
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           284924.580
# Skew:                           2.588   Prob(JB):                         0.00
# Kurtosis:                      18.649   Cond. No.                         17.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
m = ols('review_num_tokens ~ confidence_int',df_data).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      review_num_tokens   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     391.5
# Date:                Wed, 03 Jul 2024   Prob (F-statistic):           3.04e-86
# Time:                        16:01:38   Log-Likelihood:            -1.3306e+05
# No. Observations:               18434   AIC:                         2.661e+05
# Df Residuals:                   18432   BIC:                         2.661e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        285.2354     11.381     25.062      0.000     262.927     307.544
# confidence_int    58.7935      2.971     19.787      0.000      52.969      64.618
# ==============================================================================
# Omnibus:                    11037.219   Durbin-Watson:                   1.689
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           199238.987
# Skew:                           2.542   Prob(JB):                         0.00
# Kurtosis:                      18.283   Cond. No.                         19.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
                         summarize)

allvars = df_data[['rating_int', 'conf_year']]
design = MS(allvars)
X = design.fit_transform(allvars).astype(float)
y = df_data.decision == 'Reject'
glm = sm.GLM(y,
             X,
             family=sm.families.Binomial())
results = glm.fit()
summarize(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 m = ols('rating_int+conf_year ~ decision',df_data).fit()
#       2 m.summary()
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/statsmodels/base/model.py:209, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     206 max_endog = cls._formula_max_endog
#     207 if (max_endog is not None and
#     208         endog.ndim > 1 and endog.shape[1] > max_endog):
# --> 209     raise ValueError('endog has evaluated to an array with multiple '
#     210                      'columns that has shape {}. This occurs when '
#     211                      'the variable converted to endog is non-numeric'
#     212                      ' (e.g., bool or str).'.format(endog.shape))
#     213 if drop_cols is not None and len(drop_cols) > 0:
#     214     cols = [x for x in exog.columns if x not in drop_cols]
#
# ValueError: endog has evaluated to an array with multiple columns that has shape (25168, 2). This occurs when the variable converted to endog is non-numeric (e.g., bool or str).

# %%
m = ols('conf_year ~ confidence_int',df_data).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              conf_year   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     42.55
# Date:                Wed, 03 Jul 2024   Prob (F-statistic):           7.07e-11
# Time:                        16:03:18   Log-Likelihood:                -32668.
# No. Observations:               18434   AIC:                         6.534e+04
# Df Residuals:                   18432   BIC:                         6.535e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       2020.0753      0.049   4.12e+04      0.000    2019.979    2020.171
# confidence_int    -0.0836      0.013     -6.523      0.000      -0.109      -0.058
# ==============================================================================
# Omnibus:                    16023.025   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2015.457
# Skew:                          -0.548   Prob(JB):                         0.00
# Kurtosis:                       1.807   Cond. No.                         19.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Produce a graph
#
# Using the graph function below, produce a graph of the 3 top relationships you have found. Describe the graph in your paper including the summary information from m.summary() from above.
#
# What can you conclude?

# %%
#example
regression_graph('rating_int','confidence_int',df_data,'Rating vs Confidence')

# %%
# your code here
regression_graph('review_num_tokens','rating_int',df_data,'Review_num_tokens vs Rating')

# %%
regression_graph('review_num_tokens','confidence_int',df_data,'Review_num_tokens vs Confidence')

# %%
regression_graph('rating_int'+'conf_year','decision',df_data,'Rating+Conf_year vs Decision')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating_intconf_year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 regression_graph('rating_int'+'conf_year','decision',df_data,'Rating+Conf_year vs Decision')
#
# Cell In[6], line 8, in regression_graph(y, x, df, title)
#       6 # Create a regression plot
#       7 plt.figure(figsize=(10, 6))
# ----> 8 sns.regplot(y=y, x=x, data=df, fit_reg=True,
#       9             scatter_kws={'s': 50, 'alpha': 0.6, 'color': 'b'},
#      10             line_kws={'color': 'red', 'linewidth': 2})
#      12 # Customize the plot with titles and labels
#      13 plt.title(title, fontsize=20)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/seaborn/regression.py:763, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     752 def regplot(
#     753     data=None, *, x=None, y=None,
#     754     x_estimator=None, x_bins=None, x_ci="ci",
#    (...)
#     760     scatter_kws=None, line_kws=None, ax=None
#     761 ):
# --> 763     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
#     764                                  scatter, fit_reg, ci, n_boot, units, seed,
#     765                                  order, logistic, lowess, robust, logx,
#     766                                  x_partial, y_partial, truncate, dropna,
#     767                                  x_jitter, y_jitter, color, label)
#     769     if ax is None:
#     770         ax = plt.gca()
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/seaborn/regression.py:107, in _RegressionPlotter.__init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     104     raise ValueError("Mutually exclusive regression options.")
#     106 # Extract the data vals from the arguments or passed dataframe
# --> 107 self.establish_variables(data, x=x, y=y, units=units,
#     108                          x_partial=x_partial, y_partial=y_partial)
#     110 # Drop null observations
#     111 if dropna:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/seaborn/regression.py:44, in _LinearPlotter.establish_variables(self, data, **kws)
#      42 for var, val in kws.items():
#      43     if isinstance(val, str):
# ---> 44         vector = data[val]
#      45     elif isinstance(val, list):
#      46         vector = np.asarray(val)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'rating_intconf_year'

# %%
regression_graph('conf_year','confidence_int',df_data,'Conf_year vs Confidence')
